# %%
from dataclasses import dataclass
@dataclass
class Estudiante:
    nombre: str
    RUT: str
    edad: int
    nivel: int

# %%
est = Estudiante('Juanito Alcachofa', '19897263-0', 25, 4)

# %%
est.nombre
# Out:
# 'Juanito Alcachofa'
