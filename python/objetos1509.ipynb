# %%
# Declaro algo y veo su tipo, o reviso el tipo de algo que ya este 
#declarado
a = 8758
print(type(a))
print(type(print))
# Out:
# <class 'int'>
# <class 'builtin_function_or_method'>

# %%
print(f'Lista de referencias: {dir()}')
print(f'Esto es una de las referencias ocultas: {__name__}')
print(f'Documentacion generada (Oculta tambien): {__doc__}')
print(f'La direccion de a es: {id(a)}')
# Out:
# Lista de referencias: ['In', 'Out', '_', '_11', '_21', '_23', '_25', '_27', '_28', '_3', '_5', '_8', '_9', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'a', 'exit', 'get_ipython', 'open', 'pi', 'quit', 's', 's1', 'variable']
# Esto es una de las referencias ocultas: __main__
# Documentacion generada (Oculta tambien): Automatically created module for IPython interactive environment
# La direccion de a es: 2380815193488

# %%
s = 'gatito'
s1 = 'malvado'
s + ' ' + s1
# Out:
# 'gatito malvado'

# %%
lista = [0,1,2,3]
lista.append([])
lista.append(set('ab'))
#ojo
lista.append(print)

# %%
lista[6]('Hola, estoy printeando desde la lista :s')
# Out:
# Hola, estoy printeando desde la lista :s

# %%
tupla = 6,7,2,'j','a'
#funcion tupla
def paquetedetransmisiondedatos():
    return 0, []

# %%
print(f'Esta es una tupla que se retorna por la funcion: {paquetedetransmisiondedatos()}')
# Out:
# Esta es una tupla que se retorna por la funcion: (0, [])
